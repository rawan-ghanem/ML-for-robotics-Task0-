# %% [markdown]
# # Matplotlib Practice
#
# This notebook offers a set of exercises to different tasks with Matplotlib.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [Matplotlib documentation](https://matplotlib.org/3.1.1/contents.html).
#
# If you're stuck, don't forget, you can always search for a function, for example if you want to create a plot with `plt.subplots()`, search for [`plt.subplots()`](https://www.google.com/search?q=plt.subplots()).

# %%
# Import the pyplot module from matplotlib as plt and make sure 
# plots appear in the notebook using '%matplotlib inline'
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a simple plot using plt.plot()
x = [1, 1.5, 2, 2.5, 3, 3.5, 4]
y = [5, 10, 15, 20, 25, 30, 35]
plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title("A simple plot")
plt.show()

# %%
# Plot a single Python list
input = [1, 3, 5, 2, 4]
plt.plot(input)
plt.show()

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them
X = [1, 2, 3, 4, 5]
Y = [6, 7, 8, 9, 10]

# %%
# Plot X & y (the lists you've created)
plt.plot(X, label='X')
plt.plot(y, label='Y')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('X and Y')
plt.legend()
plt.show()

# %% [markdown]
# There's another way to create plots with Matplotlib, it's known as the object-orientated (OO) method. Let's try it.

# %%
# Create a plot using plt.subplots()
figure, axis = plt.subplots()
axis.plot(X)
axis.set_xlabel('X-axis label')
axis.set_ylabel('Y-axis label')
axis.set_title('Plot')
axis.grid(True)
plt.show()

# %%
# Create a plot using plt.subplots() and then add X & y on the axes
figure, axis = plt.subplots()
plt.plot(X, label='X')
plt.plot(y, label='Y')
axis.set_xlabel("X")
axis.set_ylabel("y")
axis.set_title("Plot of X and y")
plt.legend()
axis.grid(True)
plt.show()
figure.savefig("Plot of X and y")

# %% [markdown]
# Now let's try a small matplotlib workflow.

# %%
# Import and get matplotlib ready


# Prepare data (create two lists of 5 numbers, X & y)


# Setup figure and axes using plt.subplots()


# Add data (X, y) to axes


# Customize plot by adding a title, xlabel and ylabel


# Save the plot to file using fig.savefig()


# All done ^^

# %% [markdown]
# Okay, this is a simple line plot, how about something a little different?
#
# To help us, we'll import NumPy.

# %%
# Import NumPy as np
import numpy as np

# %%
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X
X = np.linspace(0, 100, 100)
print(X)
# Out:
# [  0.           1.01010101   2.02020202   3.03030303   4.04040404
#    5.05050505   6.06060606   7.07070707   8.08080808   9.09090909
#   10.1010101   11.11111111  12.12121212  13.13131313  14.14141414
#   15.15151515  16.16161616  17.17171717  18.18181818  19.19191919
#   20.2020202   21.21212121  22.22222222  23.23232323  24.24242424
#   25.25252525  26.26262626  27.27272727  28.28282828  29.29292929
#   30.3030303   31.31313131  32.32323232  33.33333333  34.34343434
#   35.35353535  36.36363636  37.37373737  38.38383838  39.39393939
#   40.4040404   41.41414141  42.42424242  43.43434343  44.44444444
#   45.45454545  46.46464646  47.47474747  48.48484848  49.49494949
#   50.50505051  51.51515152  52.52525253  53.53535354  54.54545455
#   55.55555556  56.56565657  57.57575758  58.58585859  59.5959596
#   60.60606061  61.61616162  62.62626263  63.63636364  64.64646465
#   65.65656566  66.66666667  67.67676768  68.68686869  69.6969697
#   70.70707071  71.71717172  72.72727273  73.73737374  74.74747475
#   75.75757576  76.76767677  77.77777778  78.78787879  79.7979798
#   80.80808081  81.81818182  82.82828283  83.83838384  84.84848485
#   85.85858586  86.86868687  87.87878788  88.88888889  89.8989899
#   90.90909091  91.91919192  92.92929293  93.93939394  94.94949495
#   95.95959596  96.96969697  97.97979798  98.98989899 100.        ]

# %%
# Create a plot using plt.subplots() and plot X versus X^2 (X squared)
Y = X * X
figure, axis = plt.subplots()
axis.plot(X, Y)
axis.set_title('X versus X^2')
axis.set_xlabel('X')
axis.set_ylabel('X^2')
plt.show()

# %% [markdown]
# We'll start with scatter plots.

# %%
# Create a scatter plot of X versus the exponential of X (np.exp(X))
EXP = np.exp(X)
plt.scatter(X, EXP)
plt.title('X versus exp(X)')
plt.xlabel('X')
plt.ylabel('exp(X)')
plt.show()

# %%
# Create a scatter plot of X versus np.sin(X)
SIN = np.sin(X)
plt.scatter(X, SIN)
plt.title('X versus np.sin(X)')
plt.xlabel('X')
plt.ylabel('np.sin(X)')
plt.show()

# %% [markdown]
# How about we try another type of plot? This time let's look at a bar plot. First we'll make some data.

# %%
# Create a Python dictionary of 3 of your favourite foods with 
# The keys of the dictionary should be the food name and the values their price
foods = {"Pizza": 10, "Sushi": 20, "Pad Thai": 15}

# %%
# Create a bar graph where the x-axis is the keys of the dictionary
# and the y-axis is the values of the dictionary
keys = list(foods.keys())
values = list(foods.values())
plt.bar(keys, values)
# Add a title, xlabel and ylabel to the plot
plt.title("Food Prices")
plt.xlabel("Food")
plt.ylabel("Price")
plt.show()

# %%
# Make the same plot as above, except this time make the bars go horizontal
plt.barh(keys, values)
plt.title("Food Prices")
plt.xlabel("Food")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# All this food plotting is making me hungry. But we've got a couple of plots to go.
#
# Let's see a histogram.

# %%
# Create a random NumPy array of 1000 normally distributed numbers using NumPy and save it to X
X = np.random.normal(size=1000)

# Create a histogram plot of X
plt.hist(X)
plt.title("Histogram of Normally Distributed Numbers")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# the normal distribution generated by taking the average 
# of many independent and identically distributed random variables

# %%
# Create a NumPy array of 1000 random numbers and save it to X

X = np.random.rand(1000)

# Create a histogram plot of X
plt.hist(X)
plt.title("Histogram of Normally Distributed Numbers")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# I searched for other kinds of data which may be normally distributed and found Several kinds 
# Physical measurements, academic performance, financial data, manufacturing data, environmental data

# %% [markdown]
# Notice how the distributions (spread of data) are different. Why do they differ?
#
# What else can you find out about the normal distribution?
#
# Can you think of any other kinds of data which may be normally distributed?
#
# These questions aren't directly related to plotting or Matplotlib but they're helpful to think of.
#
# Now let's try make some subplots. A subplot is another name for a figure with multiple plots on it.

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
figure, axis = plt.subplots(nrows=2, ncols=2)
plt.show()

# %% [markdown]
# Notice how the subplot has multiple figures. Now let's add data to each axes.

# %%
# Create the same plot as above with 2 rows and 2 columns and figsize of (10, 5)
fig, axs = plt.subplots(2, 2, figsize=(10, 5))
x = np.arange(10)
y = x / 2

axs[0, 0].plot(x, y)
axs[0, 0].set_title('First')

# # Plot a scatter plot of 10 random numbers on each axis on the top right subplot

z = np.random.rand(10)

axs[0, 1].scatter(x, z)
axs[0, 1].set_title('Second')

# Plot a bar graph of the favourite food keys and values on the bottom left subplot

axs[1, 0].bar(keys, values)
axs[1, 0].set_title('Third')

# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot
normal = np.random.normal(size=1000)
axs[1, 1].hist(normal)
axs[1, 1].set_title('Fourth')


plt.show()

# %%
# Import pandas as pd
import pandas as pd

# %% [markdown]
# Woah. There's a lot going on there.
#
# Now we've seen how to plot with Matplotlib and data directly. Let's practice using Matplotlib to plot with pandas.
#
# First we'll need to import pandas and create a DataFrame work with.

# %%
# Import the '../data/car-sales.csv' into a DataFame called car_sales and view
df = pd.read_csv(r"/Users/rawanghanemhmx/Desktop/Task0/data/car-sales.csv")
print(df)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Try to plot the 'Price' column using the plot() function
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Price"].plot()
plt.title("Plot of Price Column")
plt.xlabel("Index")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Why doesn't it work?
#
# Hint: It's not numeric data.
#
# In the process of turning it to numeric data, let's create another column which adds the total amount of sales and another one which shows what date the car was sold.
#
# Hint: To add a column up cumulatively, look up the cumsum() function. And to create a column of dates, look up the date_range() function.

# %%
# Remove the symbols, the final two numbers from the 'Price' column and convert it to numbers
carSales = df
carSales['Price'] = carSales['Price'].astype(str)
carSales['Price'] = carSales['Price'].str.replace('$', '').str.replace(',', '').str.replace('.', '')
print(carSales)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  \
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000
#
#                                          Total Sales  Sale Date
# 0                                            4000.00 2023-10-14
# 1                                     4000.005000.00 2023-10-15
# 2                              4000.005000.007000.00 2023-10-16
# 3                      4000.005000.007000.0022000.00 2023-10-17
# 4               4000.005000.007000.0022000.003500.00 2023-10-18
# 5        4000.005000.007000.0022000.003500.004500.00 2023-10-19
# 6  4000.005000.007000.0022000.003500.004500.00750... 2023-10-20
# 7  4000.005000.007000.0022000.003500.004500.00750... 2023-10-21
# 8  4000.005000.007000.0022000.003500.004500.00750... 2023-10-22
# 9  4000.005000.007000.0022000.003500.004500.00750... 2023-10-23

# %%
# Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column

carSales['Total Sales'] = carSales['Price'].cumsum()
print(carSales)

# Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)

from datetime import datetime

today = datetime(2023, 10, 14)

sale_dates = []
for i in range(len(carSales)):
    sale_date = today + pd.Timedelta(days=i)
    sale_dates.append(sale_date)
    
carSales['Sale Date'] = sale_dates

# View the car_sales DataFrame

print(carSales)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Total Sales   Sale Date
# 0  Toyota  White         150043      4   400000       400000  2023-10-14
# 1   Honda    Red          87899      4   500000       900000  2023-10-15
# 2  Toyota   Blue          32549      3   700000      1600000  2023-10-16
# 3     BMW  Black          11179      5  2200000      3800000  2023-10-17
# 4  Nissan  White         213095      4   350000      4150000  2023-10-18
# 5  Toyota  Green          99213      4   450000      4600000  2023-10-19
# 6   Honda   Blue          45698      4   750000      5350000  2023-10-20
# 7   Honda   Blue          54738      4   700000      6050000  2023-10-21
# 8  Toyota  White          60000      4   625000      6675000  2023-10-22
# 9  Nissan  White          31600      4   970000      7645000  2023-10-23
#      Make Colour  Odometer (KM)  Doors    Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   400000       400000 2023-10-14
# 1   Honda    Red          87899      4   500000       900000 2023-10-15
# 2  Toyota   Blue          32549      3   700000      1600000 2023-10-16
# 3     BMW  Black          11179      5  2200000      3800000 2023-10-17
# 4  Nissan  White         213095      4   350000      4150000 2023-10-18
# 5  Toyota  Green          99213      4   450000      4600000 2023-10-19
# 6   Honda   Blue          45698      4   750000      5350000 2023-10-20
# 7   Honda   Blue          54738      4   700000      6050000 2023-10-21
# 8  Toyota  White          60000      4   625000      6675000 2023-10-22
# 9  Nissan  White          31600      4   970000      7645000 2023-10-23

# %%
# Export the DataFrame you created to a .csv file
carSales.to_csv('/Users/rawanghanemhmx/Desktop/Task0/data/test.csv', index=False)

# %% [markdown]
# Now we've got a numeric column (`Total Sales`) and a dates column (`Sale Date`), let's visualize them.

# %%
# Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column
# carSales = pd.read_csv(r"/Users/rawanghanemhmx/Desktop/Task0/data/test.csv")
plt.hist(carSales)
plt.title('Total Sales vs. Sale Date')
plt.xlabel('Sale Date')
plt.ylabel('Total Sales')
plt.show()

# %%
# Convert the 'Price' column to the integers

carSales['Price'] = carSales['Price'].astype(int)

# Create a scatter plot of the 'Odometer (KM)' and 'Price' column using the plot() function

carSales.plot(x='Odometer (KM)', y='Price', kind='scatter')
plt.title('Price vs. Odometer (KM)')
plt.xlabel('Odometer (KM)')
plt.ylabel('Price')
plt.show()

# %%
# Create a NumPy array of random numbers of size (10, 4) and save it to X

X = np.random.rand(10, 4)

# Turn the NumPy array X into a DataFrame with columns called ['a', 'b', 'c', 'd']

df = pd.DataFrame(X, columns=['a', 'b', 'c', 'd'])
print(df)

# Create a bar graph of the DataFrame

df.plot.bar()
plt.title('Bar Graph of DataFrame X')
plt.xlabel('Column')
plt.ylabel('Value')
plt.show()
# Out:
#           a         b         c         d
# 0  0.958904  0.871521  0.328702  0.388073
# 1  0.877058  0.208082  0.493697  0.470898
# 2  0.309972  0.593650  0.423466  0.434634
# 3  0.810071  0.631523  0.496261  0.668298
# 4  0.277423  0.427224  0.502296  0.124897
# 5  0.488809  0.894279  0.450702  0.714559
# 6  0.810207  0.068354  0.439104  0.136184
# 7  0.245067  0.629325  0.208330  0.590627
# 8  0.957661  0.520813  0.427918  0.375367
# 9  0.995112  0.167890  0.671569  0.384863

# %%
# Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the car_sales DataFrame

carSales.groupby('Make')['Odometer (KM)'].plot(kind='bar')
plt.title('Odometer (KM) by Make')
plt.xlabel('Make')
plt.ylabel('Odometer (KM)')
plt.show()

# %%
# Create a histogram of the 'Odometer (KM)' column

carSales['Odometer (KM)'].hist()
plt.title('Histogram of Odometer (KM)')
plt.xlabel('Odometer (KM)')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a histogram of the 'Price' column with 20 bins

carSales['Price'].hist(bins=20)
plt.title('Histogram of Price with 20 Bins')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Now we've seen a few examples of plotting directly from DataFrames using the `car_sales` dataset.
#
# Let's try using a different dataset.

# %%
# Import "../data/heart-disease.csv" and save it to the variable "heart_disease"
df2 = pd.read_csv(r"/Users/rawanghanemhmx/Desktop/Task0/data/heart-disease.csv")
print(df2)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# View the first 10 rows of the heart_disease DataFrame
firstTenRows = df2.head(10)
print("First 10 rows of car sales DataFrame:", firstTenRows)
# Out:
# First 10 rows of car sales DataFrame:    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
# Create a histogram of the "age" column with 50 bins
plt.hist(df2['age'], bins=50)
plt.title('Histogram of Age Column')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Call plot.hist() on the heart_disease DataFrame and toggle the
# "subplots" parameter to True

plt.hist(df2['age'], bins=50)
plt.subplots_adjust(bottom=0.15)
plt.suptitle('Histograms of Heart Disease DataFrame')
plt.show()

# %% [markdown]
# That plot looks pretty squished. Let's change the figsize.

# %%
# Call the same line of code from above except change the "figsize" parameter
# to be (10, 30)
fig, axs = plt.subplots(figsize=(10, 30))
plt.hist(df2['age'], bins=50)
plt.suptitle('Histograms of Heart Disease DataFrame')
plt.show()

# %% [markdown]
# Now let's try comparing two variables versus the target variable.
#
# More specifially we'll see how age and cholesterol combined effect the target in **patients over 50 years old**.
#
# For this next challenge, we're going to be replicating the following plot:
#
# <img src="../images/matplotlib-heart-disease-chol-age-plot.png"/>

# %%
# Replicate the above plot in whichever way you see fit
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

axes[0, 0].hist(df2['age'], bins=50)
axes[0, 0].set_title('Age')
axes[0, 1].hist(df2['sex'], bins=2)
axes[0, 1].set_title('Sex')
axes[1, 0].hist(df2['cp'], bins=4)
axes[1, 0].set_title('CP')
axes[1, 1].hist(df2['trestbps'], bins=50)
axes[1, 1].set_title('Trestbps')
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.show()
# Note: The method below is only one way of doing it, yours might be
# slightly different

# Create DataFrame with patients over 50 years old


age = df2[df2['age'] > 50]
agedf2 = pd.DataFrame(age)
print(agedf2)

# Create the plot

df2["age"].plot()
plt.title("Plot of age > 50 ")
plt.xlabel("Index")
plt.ylabel("age")

# Plot the data
plt.show()

# Customize the plot

fig, axs = plt.subplots()
agedf2["age"].plot(color='red', linestyle='-.')
fig.suptitle('Plot of Age Column')
plt.xlabel("Index")
plt.ylabel('Age')
plt.show()

# Add a meanline

mean_age = agedf2["age"].mean()
agedf2["age"].plot(color='blue', linestyle='--')
plt.axhline(y=mean_age, color='blue', linestyle='-')
plt.legend(['Age', 'Mean Age'], loc='upper left')
plt.title("Plot of age > 50 with Meanline")
plt.xlabel("Index")
plt.ylabel("Age")
plt.show()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %% [markdown]
# Beatiful, now you've created a plot of two different variables, let's change the style.

# %%
# Check what styles are available under plt
with plt.style.context('ggplot'):
    plt.plot(agedf2["thalach"])

plt.show()

# %%
# Change the style to use "seaborn-whitegrid"
plt.style.use('seaborn-whitegrid')
plt.plot(agedf2["thalach"])
plt.show()
# Out:
# /var/folders/gn/3kz6hnl975g8q31b2pm0q92h0000gn/T/ipykernel_9268/464667091.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# Now the style has been changed, we'll replot the same figure from above and see what it looks like.
#
# If you've changed the style correctly, it should look like the following:
# <img src="../images/matplotlib-heart-disease-chol-age-plot-seaborn-whitegrid.png"/>

# %%
# Reproduce the same figure as above with the "seaborn-whitegrid" style

fig, ax = plt.subplots()

# Set the style to "seaborn-whitegrid"
plt.style.use('seaborn-whitegrid')

# Add the data
ax.plot(agedf2["thalach"])

# Set the title and labels
ax.set_title('Plot & Meanline')
ax.set_xlabel('Index')
ax.set_ylabel('Age')

# Add a meanline
mean_age = agedf2["age"].mean()
ax.axhline(y=mean_age, color='blue', linestyle='-.')
ax.legend(['Age', 'Mean Age'], loc='upper left')
plt.show()
# Out:
# /var/folders/gn/3kz6hnl975g8q31b2pm0q92h0000gn/T/ipykernel_9268/3486096975.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# Wonderful, you've changed the style of the plots and the figure is looking different but the dots aren't a very good colour.
#
# Let's change the `cmap` parameter of `scatter()` as well as the `color` parameter of `axhline()` to fix it.
#
# Completing this step correctly should result in a figure which looks like this:
# <img src="../images/matplotlib-heart-disease-chol-age-plot-cmap-change.png"/>

# %%
# Replot the same figure as above except change the "cmap" parameter
# of scatter() to "winter"
# Also change the "color" parameter of axhline() to "red"
fig, ax = plt.subplots()

# Set the style to "seaborn-whitegrid"
plt.style.use('seaborn-whitegrid')

# Add the data
# ax.plot(agedf2["thalach"])

# Set the title and labels
ax.set_title('Plot of age > 50 with Meanline')
ax.set_xlabel('Index')
ax.set_ylabel('Age')

# Add a meanline
mean_age = agedf2["age"].mean()
ax.axhline(y=mean_age, color='red', linestyle='-')

# Add a legend
ax.legend(['Age', 'Mean Age'], loc='upper left')

# Plot the data
ax.scatter(agedf2["thalach"], agedf2["age"], cmap='winter')

# Show the plot
plt.show()
# Out:
# /var/folders/gn/3kz6hnl975g8q31b2pm0q92h0000gn/T/ipykernel_9268/2360360344.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# /var/folders/gn/3kz6hnl975g8q31b2pm0q92h0000gn/T/ipykernel_9268/2360360344.py:25: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(agedf2["thalach"], agedf2["age"], cmap='winter')

# %% [markdown]
# Beautiful! Now our figure has an upgraded color scheme let's save it to file.

# %%
# Save the current figure using savefig(), the file name can be anything you want
fig.savefig('meanline & scatter.png')

# %%
# Reset the figure by calling plt.subplots()

plt.clf()
plt.title("Reset plot")
plt.show()

# %%
# for subplots 
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

axes[0, 0].hist(df2['age'], bins=50)
axes[0, 0].set_title('Age')
axes[0, 1].hist(df2['sex'], bins=2)
axes[0, 1].set_title('Sex')
axes[1, 0].hist(df2['cp'], bins=4)
axes[1, 0].set_title('CP')
axes[1, 1].hist(df2['trestbps'], bins=50)
axes[1, 1].set_title('Trestbps')
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.clf()
plt.title("Reset plot")
plt.show()

# %% [markdown]
# ## Extensions
#
# For more exercises, check out the [Matplotlib tutorials page](https://matplotlib.org/3.1.1/tutorials/index.html). A good practice would be to read through it and for the parts you find interesting, add them into the end of this notebook.
#
# The next place you could go is the [Stack Overflow page for the top questions and answers for Matplotlib](https://stackoverflow.com/questions/tagged/matplotlib?sort=MostVotes&edited=true). Often, you'll find some of the most common and useful Matplotlib functions here. Don't forget to play around with the Stack Overflow filters! You'll likely find something helpful here.
#
# Finally, as always, remember, the best way to learn something new is to try it. And try it relentlessly. Always be asking yourself, "is there a better way this data could be visualized so it's easier to understand?"
